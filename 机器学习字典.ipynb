# %% [markdown]
# ### 1.损失函数的作用：衡量模型模型预测的好坏
# 		- 损失是一个数值，表示对于单个样本而言模型预测的准确程度
#             损失是对糟糕预测的惩罚
#             训练模型的目标是从所有样本中找到一组平均损失“较小”的权重和偏差。

# %% [markdown]
# ### 2.目标函数、损失函数、代价函数有什么区别

# %% [markdown]
# ### 3.什么是张量 Tensor
# > 标量是0阶张量，向量是1阶张量，矩阵是2阶张量，三维以上的数组形式统称张量，N维数组cheng称为N阶张量。
# https://www.wukong.com/question/6531498435785261325/
# ![image.png](attachment:image.png)

# %% [markdown]
# > 张量的作用
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
